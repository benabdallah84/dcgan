# %%
from google.colab import drive
drive.mount('/content/gdive')
# Out:
# Mounted at /content/gdive

# %%
from torch.functional import broadcast_shapes
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision


import torchvision.datasets as datasets
from torch.utils.data import DataLoader

import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
from utils import save_model
#! Things to try:
#? 1. What happenes if you use larger network?
#? 2. Better normalization with batchNorm
#? 3. Better learning rate
#? 4. Change architecture to a CNN



class Discriminator(nn.Module):
    def __init__(self,channels_img, features_d):
        super(Discriminator,self).__init__()
        self.disc = nn.Sequential(
            # input: N * channels_img * 64 *64
            nn.Conv2d(channels_img, features_d, kernel_size=4,stride=2,padding=1),
            nn.LeakyReLU(0.2),# 32*32
            self._block(features_d,features_d*2,4,2,1),#16*16
            self._block(features_d*2,features_d*4,4,2,1),#8*8
            self._block(features_d*4,features_d*8,4,2,1),#4*4
            nn.Conv2d(features_d*8,1,kernel_size=4,stride=2,padding=0),#1*1
            nn.Sigmoid()
        )
        
    def _block(self,in_channels,out_channels,kernel_size,stride,padding):
        return nn.Sequential(
            nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2)
        )


    def forward(self,x):
       return self.disc(x)
        
class Generator(nn.Module):
    def __init__(self,z_dim, channels_img, features_g):
        super(Generator,self).__init__()
        self.gen = nn.Sequential(
            # input: N * z_dim * 1 * 1
            self._block(z_dim,features_g*16,4,1,0),#N*f_g*16 * 4 * 4
            self._block(features_g*16,features_g*8,4,2,1),#8*8
            self._block(features_g*8,features_g*4,4,2,1),#16*16
            self._block(features_g*4,features_g*2,4,2,1),#32*32
            nn.ConvTranspose2d(features_g*2,channels_img,kernel_size=4,stride=2,padding=1),
            nn.Tanh()#[-1,1]
            
        )
    def _block(self,in_channels,out_channels,kernel_size,stride,padding):
        return nn.Sequential(
            nn.ConvTranspose2d(in_channels,out_channels,kernel_size,stride,padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )
    def forward(self,x):
        return self.gen(x)
    
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0,0.02)

def test():
    N, in_channels,H,W = 8,3,64,64   
    z_dim = 100
    x = torch.randn(N, in_channels, H, W)
    disc = Discriminator(in_channels,8)
    initialize_weights(disc)
    assert disc(x).shape == torch.Size([N, 1,1,1])
    gen = Generator(z_dim,in_channels,8)
    initialize_weights(gen)
    z = torch.randn(N, z_dim, 1, 1)
    assert gen(z).shape == torch.Size([N, in_channels, H, W])
    print('test passed')

#test()

data_root = "/content/gdive/MyDrive/GIDS/CAN_image_dataset(L)/" 
data_save = "/content/gdive/MyDrive/GIDS/saved_model" 

#Hyperparameters
device = torch.device("cuda" if torch.cuda.is_available() else 'cpu')
lr = 2e-4
z_dim = 100
image_dim = 64
num_epoch = 100
batch_size = 128
channels_img = 1
features_disc=64
features_gen=64

my_transforms = transforms.Compose(
    [
        transforms.Resize((image_dim,image_dim)),
        transforms.ToTensor(),
        transforms.Grayscale(1),
        transforms.Normalize(
            [0.5 for _ in range(channels_img)],[0.5 for _ in range(channels_img)]

        )
        
    ])



fixed_noise = torch.randn((batch_size, z_dim)).to(device)
#transforms = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])#(0.1307,), (0.3081,)

#dataset = datasets.MNIST(root= data_root, download=True, transform=my_transforms)#'./datasets'
datasets = datasets.ImageFolder(root= data_root,
                              transform = my_transforms)

loader = torch.utils.data.DataLoader(datasets, batch_size = batch_size,shuffle=True,num_workers = 2, persistent_workers= True)
device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")

#loader = DataLoader(data_root, batch_size=batch_size, shuffle=True)

disc = Discriminator(channels_img,features_disc).to(device)
gen = Generator(z_dim, channels_img, features_gen).to(device)

disc.load_state_dict(torch.load(f=f"/content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_20.pth"))
gen.load_state_dict(torch.load(f=f"/content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_20.pth"))

#initialize_weights(disc)
#initialize_weights(gen)

opt_disc = optim.Adam(disc.parameters(), lr=lr,betas=(0.5, 0.999))
opt_gen = optim.Adam(gen.parameters(), lr=lr, betas=(0.5, 0.999))

criterion = nn.BCELoss()

fixed_noise= torch.randn(32, z_dim,1,1).to(device)


writer_fake = SummaryWriter(f"logs/fake")
writer_real = SummaryWriter(f"logs/real")

# steps to printing on tensorboard
step = 0

gen.train()
disc.train()

for epoch in range(num_epoch):
    for i, data in enumerate(loader):
        
        real_img, _ = data
        real_img = real_img.to(device)#.view(-1,784)
        #batch_size = real_img.shape[0]

        #train Discriminator: max log(D(real)) + log(1-D(G(z)))
        noise = torch.randn((batch_size, z_dim,1,1)).to(device)
        fake_img = gen(noise)
        disc_real = disc(real_img).reshape(-1)

        disc_fake = disc(fake_img.detach())
        disc_loss_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake_img).reshape(-1)
        disc_loss_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        disc_loss = (disc_loss_real + disc_loss_fake)/2
        opt_disc.zero_grad()
        disc_loss.backward(retain_graph=True)
        opt_disc.step()

        #train Generator: min log(1- log(D(G(z)))
        output = disc(fake_img).reshape(-1)
        gen_loss = criterion(output, torch.ones_like(output))
        opt_gen.zero_grad()
        gen_loss.backward()
        opt_gen.step()

        if i % 10 == 1:
            print(f"Epoch: {epoch}/{num_epoch}, Batch {i}/{len(loader)},Discriminator Loss: {disc_loss:.4f}, Generator Loss: {gen_loss:.4f}")

            with torch.no_grad():
                fake= gen(fixed_noise)#.reshape(-1,1,28,28)
                #data=real_img.reshape(-1,1,28,28)
                img_grid_fake = torchvision.utils.make_grid(fake[:32], normalize=True)
                img_grid_real = torchvision.utils.make_grid(real_img[:32], normalize=True)
                             
                writer_fake.add_image("Mnist Fake Images", img_grid_fake,global_step=step)
                writer_real.add_image("Mnist Fake Images", img_grid_real,global_step=step)
            step +=1
    
    if (epoch % 10 == 0):
        save_model(model=disc,target_dir=f"{data_save}/dcgan/discriminator/",model_name=f"discriminator_{epoch}.pth")
        save_model(model=gen,target_dir=f"{data_save}/dcgan/generator/",model_name=f"generator_{epoch}.pth")
# Out:
# Epoch: 0/100, Batch 1/44,Discriminator Loss: 0.0731, Generator Loss: 4.2985
# Epoch: 0/100, Batch 11/44,Discriminator Loss: 0.0114, Generator Loss: 5.6930
# Epoch: 0/100, Batch 21/44,Discriminator Loss: 0.0086, Generator Loss: 7.2234
# Epoch: 0/100, Batch 31/44,Discriminator Loss: 0.0080, Generator Loss: 8.2715
# Epoch: 0/100, Batch 41/44,Discriminator Loss: 0.0010, Generator Loss: 9.2720
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_0.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_0.pth
# Epoch: 1/100, Batch 1/44,Discriminator Loss: 0.0048, Generator Loss: 7.7488
# Epoch: 1/100, Batch 11/44,Discriminator Loss: 0.0367, Generator Loss: 8.5844
# Epoch: 1/100, Batch 21/44,Discriminator Loss: 0.0009, Generator Loss: 10.0541
# Epoch: 1/100, Batch 31/44,Discriminator Loss: 0.0351, Generator Loss: 5.9699
# Epoch: 1/100, Batch 41/44,Discriminator Loss: 0.5243, Generator Loss: 8.9998
# Epoch: 2/100, Batch 1/44,Discriminator Loss: 0.0127, Generator Loss: 11.2219
# Epoch: 2/100, Batch 11/44,Discriminator Loss: 0.0577, Generator Loss: 5.9799
# Epoch: 2/100, Batch 21/44,Discriminator Loss: 0.0316, Generator Loss: 6.0642
# Epoch: 2/100, Batch 31/44,Discriminator Loss: 0.0189, Generator Loss: 7.4803
# Epoch: 2/100, Batch 41/44,Discriminator Loss: 0.0055, Generator Loss: 8.3225
# Epoch: 3/100, Batch 1/44,Discriminator Loss: 0.0637, Generator Loss: 8.5121
# Epoch: 3/100, Batch 11/44,Discriminator Loss: 0.0433, Generator Loss: 6.0308
# Epoch: 3/100, Batch 21/44,Discriminator Loss: 0.3914, Generator Loss: 10.6509
# Epoch: 3/100, Batch 31/44,Discriminator Loss: 0.0100, Generator Loss: 7.4570
# Epoch: 3/100, Batch 41/44,Discriminator Loss: 0.0322, Generator Loss: 4.6297
# Epoch: 4/100, Batch 1/44,Discriminator Loss: 0.0264, Generator Loss: 4.4877
# Epoch: 4/100, Batch 11/44,Discriminator Loss: 0.0574, Generator Loss: 4.0103
# Epoch: 4/100, Batch 21/44,Discriminator Loss: 0.0868, Generator Loss: 5.6136
# Epoch: 4/100, Batch 31/44,Discriminator Loss: 0.0597, Generator Loss: 10.0187
# Epoch: 4/100, Batch 41/44,Discriminator Loss: 0.0859, Generator Loss: 6.3823
# Epoch: 5/100, Batch 1/44,Discriminator Loss: 0.0207, Generator Loss: 4.7091
# Epoch: 5/100, Batch 11/44,Discriminator Loss: 0.0325, Generator Loss: 5.0298
# Epoch: 5/100, Batch 21/44,Discriminator Loss: 0.5033, Generator Loss: 10.3065
# Epoch: 5/100, Batch 31/44,Discriminator Loss: 0.0200, Generator Loss: 8.3188
# Epoch: 5/100, Batch 41/44,Discriminator Loss: 0.0648, Generator Loss: 5.7596
# Epoch: 6/100, Batch 1/44,Discriminator Loss: 0.0491, Generator Loss: 5.0728
# Epoch: 6/100, Batch 11/44,Discriminator Loss: 0.0971, Generator Loss: 7.0983
# Epoch: 6/100, Batch 21/44,Discriminator Loss: 0.0008, Generator Loss: 7.3947
# Epoch: 6/100, Batch 31/44,Discriminator Loss: 0.0189, Generator Loss: 4.1664
# Epoch: 6/100, Batch 41/44,Discriminator Loss: 0.1364, Generator Loss: 7.2048
# Epoch: 7/100, Batch 1/44,Discriminator Loss: 0.0191, Generator Loss: 4.6847
# Epoch: 7/100, Batch 11/44,Discriminator Loss: 0.0968, Generator Loss: 7.0197
# Epoch: 7/100, Batch 21/44,Discriminator Loss: 0.0169, Generator Loss: 5.6519
# Epoch: 7/100, Batch 31/44,Discriminator Loss: 0.0468, Generator Loss: 5.1472
# Epoch: 7/100, Batch 41/44,Discriminator Loss: 0.0279, Generator Loss: 5.8064
# Epoch: 8/100, Batch 1/44,Discriminator Loss: 0.0372, Generator Loss: 6.1985
# Epoch: 8/100, Batch 11/44,Discriminator Loss: 0.0752, Generator Loss: 8.6374
# Epoch: 8/100, Batch 21/44,Discriminator Loss: 0.0372, Generator Loss: 5.8521
# Epoch: 8/100, Batch 31/44,Discriminator Loss: 0.0080, Generator Loss: 6.2744
# Epoch: 8/100, Batch 41/44,Discriminator Loss: 0.0167, Generator Loss: 5.9793
# Epoch: 9/100, Batch 1/44,Discriminator Loss: 0.0219, Generator Loss: 5.4524
# Epoch: 9/100, Batch 11/44,Discriminator Loss: 2.4758, Generator Loss: 13.8006
# Epoch: 9/100, Batch 21/44,Discriminator Loss: 0.0347, Generator Loss: 3.3123
# Epoch: 9/100, Batch 31/44,Discriminator Loss: 0.0702, Generator Loss: 5.9315
# Epoch: 9/100, Batch 41/44,Discriminator Loss: 0.0477, Generator Loss: 7.3916
# Epoch: 10/100, Batch 1/44,Discriminator Loss: 0.0277, Generator Loss: 3.5734
# Epoch: 10/100, Batch 11/44,Discriminator Loss: 0.0714, Generator Loss: 4.7185
# Epoch: 10/100, Batch 21/44,Discriminator Loss: 0.0794, Generator Loss: 6.6297
# Epoch: 10/100, Batch 31/44,Discriminator Loss: 0.0382, Generator Loss: 4.8210
# Epoch: 10/100, Batch 41/44,Discriminator Loss: 0.0449, Generator Loss: 4.8350
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_10.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_10.pth
# Epoch: 11/100, Batch 1/44,Discriminator Loss: 0.0098, Generator Loss: 4.5699
# Epoch: 11/100, Batch 11/44,Discriminator Loss: 0.0960, Generator Loss: 6.2264
# Epoch: 11/100, Batch 21/44,Discriminator Loss: 0.0687, Generator Loss: 8.3286
# Epoch: 11/100, Batch 31/44,Discriminator Loss: 0.0210, Generator Loss: 12.0631
# Epoch: 11/100, Batch 41/44,Discriminator Loss: 0.1045, Generator Loss: 7.2243
# Epoch: 12/100, Batch 1/44,Discriminator Loss: 0.0291, Generator Loss: 8.3725
# Epoch: 12/100, Batch 11/44,Discriminator Loss: 0.0290, Generator Loss: 11.0181
# Epoch: 12/100, Batch 21/44,Discriminator Loss: 0.0196, Generator Loss: 14.5816
# Epoch: 12/100, Batch 31/44,Discriminator Loss: 0.1372, Generator Loss: 6.1256
# Epoch: 12/100, Batch 41/44,Discriminator Loss: 0.0707, Generator Loss: 5.6320
# Epoch: 13/100, Batch 1/44,Discriminator Loss: 0.0924, Generator Loss: 7.3168
# Epoch: 13/100, Batch 11/44,Discriminator Loss: 0.0035, Generator Loss: 10.6152
# Epoch: 13/100, Batch 21/44,Discriminator Loss: 0.0082, Generator Loss: 4.8008
# Epoch: 13/100, Batch 31/44,Discriminator Loss: 0.5420, Generator Loss: 12.9778
# Epoch: 13/100, Batch 41/44,Discriminator Loss: 0.0214, Generator Loss: 5.9333
# Epoch: 14/100, Batch 1/44,Discriminator Loss: 0.0618, Generator Loss: 6.1689
# Epoch: 14/100, Batch 11/44,Discriminator Loss: 0.0944, Generator Loss: 5.6720
# Epoch: 14/100, Batch 21/44,Discriminator Loss: 0.0755, Generator Loss: 7.6897
# Epoch: 14/100, Batch 31/44,Discriminator Loss: 0.0610, Generator Loss: 7.9702
# Epoch: 14/100, Batch 41/44,Discriminator Loss: 0.0001, Generator Loss: 9.9531
# Epoch: 15/100, Batch 1/44,Discriminator Loss: 0.0089, Generator Loss: 4.3934
# Epoch: 15/100, Batch 11/44,Discriminator Loss: 0.0281, Generator Loss: 5.2255
# Epoch: 15/100, Batch 21/44,Discriminator Loss: 0.1548, Generator Loss: 9.6865
# Epoch: 15/100, Batch 31/44,Discriminator Loss: 0.0904, Generator Loss: 7.7508
# Epoch: 15/100, Batch 41/44,Discriminator Loss: 0.0923, Generator Loss: 9.9706
# Epoch: 16/100, Batch 1/44,Discriminator Loss: 0.3735, Generator Loss: 12.8252
# Epoch: 16/100, Batch 11/44,Discriminator Loss: 0.0633, Generator Loss: 5.8199
# Epoch: 16/100, Batch 21/44,Discriminator Loss: 0.0205, Generator Loss: 7.9661
# Epoch: 16/100, Batch 31/44,Discriminator Loss: 0.1087, Generator Loss: 10.6258
# Epoch: 16/100, Batch 41/44,Discriminator Loss: 0.0350, Generator Loss: 7.1065
# Epoch: 17/100, Batch 1/44,Discriminator Loss: 0.0368, Generator Loss: 5.9131
# Epoch: 17/100, Batch 11/44,Discriminator Loss: 0.0860, Generator Loss: 11.1319
# Epoch: 17/100, Batch 21/44,Discriminator Loss: 0.0005, Generator Loss: 10.4038
# Epoch: 17/100, Batch 31/44,Discriminator Loss: 0.0415, Generator Loss: 5.9925
# Epoch: 17/100, Batch 41/44,Discriminator Loss: 0.0294, Generator Loss: 8.3871
# Epoch: 18/100, Batch 1/44,Discriminator Loss: 0.0260, Generator Loss: 7.3379
# Epoch: 18/100, Batch 11/44,Discriminator Loss: 0.5135, Generator Loss: 13.8522
# Epoch: 18/100, Batch 21/44,Discriminator Loss: 0.0134, Generator Loss: 6.3201
# Epoch: 18/100, Batch 31/44,Discriminator Loss: 0.0170, Generator Loss: 4.5309
# Epoch: 18/100, Batch 41/44,Discriminator Loss: 0.0194, Generator Loss: 7.9843
# Epoch: 19/100, Batch 1/44,Discriminator Loss: 0.0564, Generator Loss: 6.7644
# Epoch: 19/100, Batch 11/44,Discriminator Loss: 0.1449, Generator Loss: 8.8264
# Epoch: 19/100, Batch 21/44,Discriminator Loss: 0.0432, Generator Loss: 8.9717
# Epoch: 19/100, Batch 31/44,Discriminator Loss: 0.0722, Generator Loss: 6.0449
# Epoch: 19/100, Batch 41/44,Discriminator Loss: 0.2978, Generator Loss: 12.9085
# Epoch: 20/100, Batch 1/44,Discriminator Loss: 0.0023, Generator Loss: 5.5534
# Epoch: 20/100, Batch 11/44,Discriminator Loss: 0.1246, Generator Loss: 4.8334
# Epoch: 20/100, Batch 21/44,Discriminator Loss: 0.3843, Generator Loss: 10.9181
# Epoch: 20/100, Batch 31/44,Discriminator Loss: 0.3685, Generator Loss: 7.4266
# Epoch: 20/100, Batch 41/44,Discriminator Loss: 0.7497, Generator Loss: 12.6308
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_20.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_20.pth
# Epoch: 21/100, Batch 1/44,Discriminator Loss: 0.0079, Generator Loss: 4.6704
# Epoch: 21/100, Batch 11/44,Discriminator Loss: 0.0246, Generator Loss: 4.4004
# Epoch: 21/100, Batch 21/44,Discriminator Loss: 0.2089, Generator Loss: 7.6690
# Epoch: 21/100, Batch 31/44,Discriminator Loss: 0.3414, Generator Loss: 11.7797
# Epoch: 21/100, Batch 41/44,Discriminator Loss: 0.1753, Generator Loss: 4.6947
# Epoch: 22/100, Batch 1/44,Discriminator Loss: 0.6791, Generator Loss: 13.5345
# Epoch: 22/100, Batch 11/44,Discriminator Loss: 0.0653, Generator Loss: 5.5729
# Epoch: 22/100, Batch 21/44,Discriminator Loss: 0.1969, Generator Loss: 10.5046
# Epoch: 22/100, Batch 31/44,Discriminator Loss: 0.0930, Generator Loss: 6.6604
# Epoch: 22/100, Batch 41/44,Discriminator Loss: 0.0521, Generator Loss: 5.2090
# Epoch: 23/100, Batch 1/44,Discriminator Loss: 0.0603, Generator Loss: 5.1152
# Epoch: 23/100, Batch 11/44,Discriminator Loss: 0.0617, Generator Loss: 5.8302
# Epoch: 23/100, Batch 21/44,Discriminator Loss: 0.0958, Generator Loss: 5.4365
# Epoch: 23/100, Batch 31/44,Discriminator Loss: 0.0464, Generator Loss: 6.2372
# Epoch: 23/100, Batch 41/44,Discriminator Loss: 3.1735, Generator Loss: 15.3733
# Epoch: 24/100, Batch 1/44,Discriminator Loss: 0.0001, Generator Loss: 10.0583
# Epoch: 24/100, Batch 11/44,Discriminator Loss: 0.0226, Generator Loss: 5.5077
# Epoch: 24/100, Batch 21/44,Discriminator Loss: 0.1372, Generator Loss: 8.5421
# Epoch: 24/100, Batch 31/44,Discriminator Loss: 0.0620, Generator Loss: 4.6374
# Epoch: 24/100, Batch 41/44,Discriminator Loss: 0.0221, Generator Loss: 7.7291
# Epoch: 25/100, Batch 1/44,Discriminator Loss: 0.1501, Generator Loss: 12.7145
# Epoch: 25/100, Batch 11/44,Discriminator Loss: 0.0612, Generator Loss: 6.5741
# Epoch: 25/100, Batch 21/44,Discriminator Loss: 0.0184, Generator Loss: 5.1958
# Epoch: 25/100, Batch 31/44,Discriminator Loss: 0.0125, Generator Loss: 4.3850
# Epoch: 25/100, Batch 41/44,Discriminator Loss: 0.1188, Generator Loss: 12.4024
# Epoch: 26/100, Batch 1/44,Discriminator Loss: 0.0292, Generator Loss: 4.2788
# Epoch: 26/100, Batch 11/44,Discriminator Loss: 0.0700, Generator Loss: 5.5062
# Epoch: 26/100, Batch 21/44,Discriminator Loss: 0.0398, Generator Loss: 8.0558
# Epoch: 26/100, Batch 31/44,Discriminator Loss: 0.3708, Generator Loss: 14.9765
# Epoch: 26/100, Batch 41/44,Discriminator Loss: 0.0352, Generator Loss: 7.3098
# Epoch: 27/100, Batch 1/44,Discriminator Loss: 0.1369, Generator Loss: 9.6243
# Epoch: 27/100, Batch 11/44,Discriminator Loss: 0.0593, Generator Loss: 6.3786
# Epoch: 27/100, Batch 21/44,Discriminator Loss: 0.0352, Generator Loss: 5.8082
# Epoch: 27/100, Batch 31/44,Discriminator Loss: 0.0280, Generator Loss: 6.4237
# Epoch: 27/100, Batch 41/44,Discriminator Loss: 0.0114, Generator Loss: 11.5304
# Epoch: 28/100, Batch 1/44,Discriminator Loss: 0.0748, Generator Loss: 10.8279
# Epoch: 28/100, Batch 11/44,Discriminator Loss: 0.0295, Generator Loss: 5.8466
# Epoch: 28/100, Batch 21/44,Discriminator Loss: 0.0024, Generator Loss: 9.6867
# Epoch: 28/100, Batch 31/44,Discriminator Loss: 0.1789, Generator Loss: 12.3890
# Epoch: 28/100, Batch 41/44,Discriminator Loss: 0.1018, Generator Loss: 8.9582
# Epoch: 29/100, Batch 1/44,Discriminator Loss: 0.0786, Generator Loss: 12.7769
# Epoch: 29/100, Batch 11/44,Discriminator Loss: 0.1205, Generator Loss: 10.6093
# Epoch: 29/100, Batch 21/44,Discriminator Loss: 0.0006, Generator Loss: 9.4538
# Epoch: 29/100, Batch 31/44,Discriminator Loss: 0.0685, Generator Loss: 10.1157
# Epoch: 29/100, Batch 41/44,Discriminator Loss: 0.0015, Generator Loss: 9.0339
# Epoch: 30/100, Batch 1/44,Discriminator Loss: 0.0367, Generator Loss: 6.7026
# Epoch: 30/100, Batch 11/44,Discriminator Loss: 0.1110, Generator Loss: 12.0188
# Epoch: 30/100, Batch 21/44,Discriminator Loss: 0.0372, Generator Loss: 5.4511
# Epoch: 30/100, Batch 31/44,Discriminator Loss: 0.1094, Generator Loss: 9.7771
# Epoch: 30/100, Batch 41/44,Discriminator Loss: 0.0464, Generator Loss: 6.5220
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_30.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_30.pth
# Epoch: 31/100, Batch 1/44,Discriminator Loss: 0.0415, Generator Loss: 6.7212
# Epoch: 31/100, Batch 11/44,Discriminator Loss: 1.2678, Generator Loss: 17.5936
# Epoch: 31/100, Batch 21/44,Discriminator Loss: 0.0001, Generator Loss: 13.3098
# Epoch: 31/100, Batch 31/44,Discriminator Loss: 0.0281, Generator Loss: 4.7596
# Epoch: 31/100, Batch 41/44,Discriminator Loss: 0.0257, Generator Loss: 4.1635
# Epoch: 32/100, Batch 1/44,Discriminator Loss: 0.0556, Generator Loss: 7.3690
# Epoch: 32/100, Batch 11/44,Discriminator Loss: 0.0126, Generator Loss: 7.1908
# Epoch: 32/100, Batch 21/44,Discriminator Loss: 0.3947, Generator Loss: 12.9543
# Epoch: 32/100, Batch 31/44,Discriminator Loss: 0.0751, Generator Loss: 8.1765
# Epoch: 32/100, Batch 41/44,Discriminator Loss: 0.0021, Generator Loss: 6.1055
# Epoch: 33/100, Batch 1/44,Discriminator Loss: 0.0248, Generator Loss: 11.8906
# Epoch: 33/100, Batch 11/44,Discriminator Loss: 0.0361, Generator Loss: 4.2273
# Epoch: 33/100, Batch 21/44,Discriminator Loss: 0.0414, Generator Loss: 6.2444
# Epoch: 33/100, Batch 31/44,Discriminator Loss: 0.0765, Generator Loss: 6.6712
# Epoch: 33/100, Batch 41/44,Discriminator Loss: 0.0054, Generator Loss: 12.9137
# Epoch: 34/100, Batch 1/44,Discriminator Loss: 0.0154, Generator Loss: 4.9537
# Epoch: 34/100, Batch 11/44,Discriminator Loss: 0.0346, Generator Loss: 5.2273
# Epoch: 34/100, Batch 21/44,Discriminator Loss: 0.0314, Generator Loss: 5.5394
# Epoch: 34/100, Batch 31/44,Discriminator Loss: 0.0668, Generator Loss: 8.8311
# Epoch: 34/100, Batch 41/44,Discriminator Loss: 0.0276, Generator Loss: 5.4882
# Epoch: 35/100, Batch 1/44,Discriminator Loss: 0.0530, Generator Loss: 8.3881
# Epoch: 35/100, Batch 11/44,Discriminator Loss: 0.0021, Generator Loss: 5.7749
# Epoch: 35/100, Batch 21/44,Discriminator Loss: 0.0674, Generator Loss: 6.2915
# Epoch: 35/100, Batch 31/44,Discriminator Loss: 0.0009, Generator Loss: 11.9158
# Epoch: 35/100, Batch 41/44,Discriminator Loss: 0.0089, Generator Loss: 8.1812
# Epoch: 36/100, Batch 1/44,Discriminator Loss: 0.0256, Generator Loss: 8.1222
# Epoch: 36/100, Batch 11/44,Discriminator Loss: 0.0278, Generator Loss: 11.2909
# Epoch: 36/100, Batch 21/44,Discriminator Loss: 0.0283, Generator Loss: 5.5884
# Epoch: 36/100, Batch 31/44,Discriminator Loss: 0.0291, Generator Loss: 5.3036
# Epoch: 36/100, Batch 41/44,Discriminator Loss: 0.0335, Generator Loss: 5.4229
# Epoch: 37/100, Batch 1/44,Discriminator Loss: 0.0562, Generator Loss: 8.2210
# Epoch: 37/100, Batch 11/44,Discriminator Loss: 0.0034, Generator Loss: 11.0088
# Epoch: 37/100, Batch 21/44,Discriminator Loss: 0.0338, Generator Loss: 7.1641
# Epoch: 37/100, Batch 31/44,Discriminator Loss: 0.0454, Generator Loss: 6.7504
# Epoch: 37/100, Batch 41/44,Discriminator Loss: 0.0021, Generator Loss: 18.3580
# Epoch: 38/100, Batch 1/44,Discriminator Loss: 0.0008, Generator Loss: 13.4075
# Epoch: 38/100, Batch 11/44,Discriminator Loss: 0.0790, Generator Loss: 6.9209
# Epoch: 38/100, Batch 21/44,Discriminator Loss: 0.0373, Generator Loss: 6.2258
# Epoch: 38/100, Batch 31/44,Discriminator Loss: 0.1815, Generator Loss: 14.0294
# Epoch: 38/100, Batch 41/44,Discriminator Loss: 0.0399, Generator Loss: 5.1909
# Epoch: 39/100, Batch 1/44,Discriminator Loss: 0.0485, Generator Loss: 5.3031
# Epoch: 39/100, Batch 11/44,Discriminator Loss: 0.0338, Generator Loss: 6.7351
# Epoch: 39/100, Batch 21/44,Discriminator Loss: 0.0686, Generator Loss: 8.4661
# Epoch: 39/100, Batch 31/44,Discriminator Loss: 0.0212, Generator Loss: 6.6099
# Epoch: 39/100, Batch 41/44,Discriminator Loss: 0.0120, Generator Loss: 6.4049
# Epoch: 40/100, Batch 1/44,Discriminator Loss: 0.0011, Generator Loss: 12.3015
# Epoch: 40/100, Batch 11/44,Discriminator Loss: 0.0166, Generator Loss: 7.3943
# Epoch: 40/100, Batch 21/44,Discriminator Loss: 0.0193, Generator Loss: 6.2998
# Epoch: 40/100, Batch 31/44,Discriminator Loss: 0.0237, Generator Loss: 7.6692
# Epoch: 40/100, Batch 41/44,Discriminator Loss: 0.0158, Generator Loss: 9.4857
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_40.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_40.pth
# Epoch: 41/100, Batch 1/44,Discriminator Loss: 0.0113, Generator Loss: 8.1900
# Epoch: 41/100, Batch 11/44,Discriminator Loss: 0.0363, Generator Loss: 10.4768
# Epoch: 41/100, Batch 21/44,Discriminator Loss: 0.1472, Generator Loss: 19.0085
# Epoch: 41/100, Batch 31/44,Discriminator Loss: 0.0008, Generator Loss: 8.1154
# Epoch: 41/100, Batch 41/44,Discriminator Loss: 0.0525, Generator Loss: 9.4594
# Epoch: 42/100, Batch 1/44,Discriminator Loss: 0.0176, Generator Loss: 7.6699
# Epoch: 42/100, Batch 11/44,Discriminator Loss: 0.0007, Generator Loss: 13.3562
# Epoch: 42/100, Batch 21/44,Discriminator Loss: 0.0063, Generator Loss: 6.4461
# Epoch: 42/100, Batch 31/44,Discriminator Loss: 0.0270, Generator Loss: 9.6515
# Epoch: 42/100, Batch 41/44,Discriminator Loss: 0.0035, Generator Loss: 5.9757
# Epoch: 43/100, Batch 1/44,Discriminator Loss: 0.0054, Generator Loss: 7.6204
# Epoch: 43/100, Batch 11/44,Discriminator Loss: 0.0048, Generator Loss: 6.5961
# Epoch: 43/100, Batch 21/44,Discriminator Loss: 0.0148, Generator Loss: 6.8351
# Epoch: 43/100, Batch 31/44,Discriminator Loss: 0.0101, Generator Loss: 6.5229
# Epoch: 43/100, Batch 41/44,Discriminator Loss: 0.0647, Generator Loss: 11.3818
# Epoch: 44/100, Batch 1/44,Discriminator Loss: 0.0041, Generator Loss: 7.9937
# Epoch: 44/100, Batch 11/44,Discriminator Loss: 0.0571, Generator Loss: 9.6633
# Epoch: 44/100, Batch 21/44,Discriminator Loss: 0.0365, Generator Loss: 6.9383
# Epoch: 44/100, Batch 31/44,Discriminator Loss: 0.0000, Generator Loss: 12.2471
# Epoch: 44/100, Batch 41/44,Discriminator Loss: 0.1612, Generator Loss: 11.2212
# Epoch: 45/100, Batch 1/44,Discriminator Loss: 0.0094, Generator Loss: 6.6036
# Epoch: 45/100, Batch 11/44,Discriminator Loss: 0.0074, Generator Loss: 8.5781
# Epoch: 45/100, Batch 21/44,Discriminator Loss: 0.0230, Generator Loss: 5.0617
# Epoch: 45/100, Batch 31/44,Discriminator Loss: 0.0081, Generator Loss: 4.8526
# Epoch: 45/100, Batch 41/44,Discriminator Loss: 0.0253, Generator Loss: 5.6791
# Epoch: 46/100, Batch 1/44,Discriminator Loss: 0.0260, Generator Loss: 6.1918
# Epoch: 46/100, Batch 11/44,Discriminator Loss: 0.0247, Generator Loss: 12.8977
# Epoch: 46/100, Batch 21/44,Discriminator Loss: 1.1588, Generator Loss: 19.9862
# Epoch: 46/100, Batch 31/44,Discriminator Loss: 0.0018, Generator Loss: 14.3888
# Epoch: 46/100, Batch 41/44,Discriminator Loss: 0.0509, Generator Loss: 6.2835
# Epoch: 47/100, Batch 1/44,Discriminator Loss: 0.0480, Generator Loss: 6.2017
# Epoch: 47/100, Batch 11/44,Discriminator Loss: 0.0187, Generator Loss: 5.1131
# Epoch: 47/100, Batch 21/44,Discriminator Loss: 0.0283, Generator Loss: 6.0027
# Epoch: 47/100, Batch 31/44,Discriminator Loss: 0.0523, Generator Loss: 8.2376
# Epoch: 47/100, Batch 41/44,Discriminator Loss: 0.0225, Generator Loss: 7.1716
# Epoch: 48/100, Batch 1/44,Discriminator Loss: 0.0196, Generator Loss: 7.3030
# Epoch: 48/100, Batch 11/44,Discriminator Loss: 0.0229, Generator Loss: 6.9324
# Epoch: 48/100, Batch 21/44,Discriminator Loss: 0.0196, Generator Loss: 6.1093
# Epoch: 48/100, Batch 31/44,Discriminator Loss: 0.0012, Generator Loss: 10.7145
# Epoch: 48/100, Batch 41/44,Discriminator Loss: 0.0322, Generator Loss: 6.3451
# Epoch: 49/100, Batch 1/44,Discriminator Loss: 0.0349, Generator Loss: 6.4169
# Epoch: 49/100, Batch 11/44,Discriminator Loss: 0.0307, Generator Loss: 7.3548
# Epoch: 49/100, Batch 21/44,Discriminator Loss: 0.0142, Generator Loss: 6.2465
# Epoch: 49/100, Batch 31/44,Discriminator Loss: 0.0525, Generator Loss: 9.8270
# Epoch: 49/100, Batch 41/44,Discriminator Loss: 0.0324, Generator Loss: 6.2404
# Epoch: 50/100, Batch 1/44,Discriminator Loss: 0.1202, Generator Loss: 15.6927
# Epoch: 50/100, Batch 11/44,Discriminator Loss: 0.0127, Generator Loss: 15.6854
# Epoch: 50/100, Batch 21/44,Discriminator Loss: 0.0114, Generator Loss: 5.6759
# Epoch: 50/100, Batch 31/44,Discriminator Loss: 0.0209, Generator Loss: 7.3548
# Epoch: 50/100, Batch 41/44,Discriminator Loss: 0.0069, Generator Loss: 8.4247
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_50.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_50.pth
# Epoch: 51/100, Batch 1/44,Discriminator Loss: 0.0387, Generator Loss: 10.4258
# Epoch: 51/100, Batch 11/44,Discriminator Loss: 0.0400, Generator Loss: 13.5396
# Epoch: 51/100, Batch 21/44,Discriminator Loss: 0.0135, Generator Loss: 5.2574
# Epoch: 51/100, Batch 31/44,Discriminator Loss: 0.1073, Generator Loss: 15.5290
# Epoch: 51/100, Batch 41/44,Discriminator Loss: 0.0160, Generator Loss: 5.9134
# Epoch: 52/100, Batch 1/44,Discriminator Loss: 0.0140, Generator Loss: 6.6928
# Epoch: 52/100, Batch 11/44,Discriminator Loss: 0.0202, Generator Loss: 6.5410
# Epoch: 52/100, Batch 21/44,Discriminator Loss: 0.0070, Generator Loss: 7.4164
# Epoch: 52/100, Batch 31/44,Discriminator Loss: 0.0239, Generator Loss: 8.5015
# Epoch: 52/100, Batch 41/44,Discriminator Loss: 0.0123, Generator Loss: 7.4922
# Epoch: 53/100, Batch 1/44,Discriminator Loss: 0.0127, Generator Loss: 8.9205
# Epoch: 53/100, Batch 11/44,Discriminator Loss: 0.0249, Generator Loss: 7.8937
# Epoch: 53/100, Batch 21/44,Discriminator Loss: 0.0165, Generator Loss: 6.0314
# Epoch: 53/100, Batch 31/44,Discriminator Loss: 0.0263, Generator Loss: 7.8316
# Epoch: 53/100, Batch 41/44,Discriminator Loss: 0.0096, Generator Loss: 7.6346
# Epoch: 54/100, Batch 1/44,Discriminator Loss: 0.0107, Generator Loss: 7.1594
# Epoch: 54/100, Batch 11/44,Discriminator Loss: 0.0120, Generator Loss: 7.4918
# Epoch: 54/100, Batch 21/44,Discriminator Loss: 0.0080, Generator Loss: 7.8563
# Epoch: 54/100, Batch 31/44,Discriminator Loss: 0.0057, Generator Loss: 10.1959
# Epoch: 54/100, Batch 41/44,Discriminator Loss: 0.0174, Generator Loss: 6.0449
# Epoch: 55/100, Batch 1/44,Discriminator Loss: 0.0135, Generator Loss: 6.2736
# Epoch: 55/100, Batch 11/44,Discriminator Loss: 0.0135, Generator Loss: 7.0512
# Epoch: 55/100, Batch 21/44,Discriminator Loss: 0.0196, Generator Loss: 7.2317
# Epoch: 55/100, Batch 31/44,Discriminator Loss: 0.0072, Generator Loss: 9.0739
# Epoch: 55/100, Batch 41/44,Discriminator Loss: 0.0053, Generator Loss: 6.2369
# Epoch: 56/100, Batch 1/44,Discriminator Loss: 0.0078, Generator Loss: 6.7251
# Epoch: 56/100, Batch 11/44,Discriminator Loss: 0.0091, Generator Loss: 7.7746
# Epoch: 56/100, Batch 21/44,Discriminator Loss: 0.0080, Generator Loss: 5.9255
# Epoch: 56/100, Batch 31/44,Discriminator Loss: 0.0122, Generator Loss: 7.7545
# Epoch: 56/100, Batch 41/44,Discriminator Loss: 0.0104, Generator Loss: 6.2306
# Epoch: 57/100, Batch 1/44,Discriminator Loss: 0.0090, Generator Loss: 6.5421
# Epoch: 57/100, Batch 11/44,Discriminator Loss: 0.0127, Generator Loss: 6.5257
# Epoch: 57/100, Batch 21/44,Discriminator Loss: 0.0095, Generator Loss: 7.1051
# Epoch: 57/100, Batch 31/44,Discriminator Loss: 0.0065, Generator Loss: 6.9351
# Epoch: 57/100, Batch 41/44,Discriminator Loss: 0.0181, Generator Loss: 6.2506
# Epoch: 58/100, Batch 1/44,Discriminator Loss: 0.0120, Generator Loss: 8.0384
# Epoch: 58/100, Batch 11/44,Discriminator Loss: 0.0088, Generator Loss: 7.0277
# Epoch: 58/100, Batch 21/44,Discriminator Loss: 0.0129, Generator Loss: 7.6325
# Epoch: 58/100, Batch 31/44,Discriminator Loss: 0.0143, Generator Loss: 8.2784
# Epoch: 58/100, Batch 41/44,Discriminator Loss: 0.0033, Generator Loss: 6.6247
# Epoch: 59/100, Batch 1/44,Discriminator Loss: 0.0051, Generator Loss: 6.6762
# Epoch: 59/100, Batch 11/44,Discriminator Loss: 0.0033, Generator Loss: 7.8586
# Epoch: 59/100, Batch 21/44,Discriminator Loss: 0.0039, Generator Loss: 7.1036
# Epoch: 59/100, Batch 31/44,Discriminator Loss: 0.0030, Generator Loss: 7.0675
# Epoch: 59/100, Batch 41/44,Discriminator Loss: 0.0056, Generator Loss: 8.0710
# Epoch: 60/100, Batch 1/44,Discriminator Loss: 0.0060, Generator Loss: 7.5987
# Epoch: 60/100, Batch 11/44,Discriminator Loss: 0.0109, Generator Loss: 6.9398
# Epoch: 60/100, Batch 21/44,Discriminator Loss: 0.0061, Generator Loss: 6.6947
# Epoch: 60/100, Batch 31/44,Discriminator Loss: 0.0063, Generator Loss: 8.1251
# Epoch: 60/100, Batch 41/44,Discriminator Loss: 0.0007, Generator Loss: 8.4759
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_60.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_60.pth
# Epoch: 61/100, Batch 1/44,Discriminator Loss: 0.0018, Generator Loss: 8.5852
# Epoch: 61/100, Batch 11/44,Discriminator Loss: 0.0165, Generator Loss: 8.0449
# Epoch: 61/100, Batch 21/44,Discriminator Loss: 0.0078, Generator Loss: 6.2464
# Epoch: 61/100, Batch 31/44,Discriminator Loss: 0.0024, Generator Loss: 6.1231
# Epoch: 61/100, Batch 41/44,Discriminator Loss: 0.0037, Generator Loss: 6.0289
# Epoch: 62/100, Batch 1/44,Discriminator Loss: 0.0312, Generator Loss: 12.9520
# Epoch: 62/100, Batch 11/44,Discriminator Loss: 0.0065, Generator Loss: 8.0784
# Epoch: 62/100, Batch 21/44,Discriminator Loss: 0.0054, Generator Loss: 12.4107
# Epoch: 62/100, Batch 31/44,Discriminator Loss: 0.0089, Generator Loss: 7.8229
# Epoch: 62/100, Batch 41/44,Discriminator Loss: 0.0072, Generator Loss: 7.7392
# Epoch: 63/100, Batch 1/44,Discriminator Loss: 0.0139, Generator Loss: 8.7989
# Epoch: 63/100, Batch 11/44,Discriminator Loss: 0.0001, Generator Loss: 10.4209
# Epoch: 63/100, Batch 21/44,Discriminator Loss: 0.0028, Generator Loss: 9.0591
# Epoch: 63/100, Batch 31/44,Discriminator Loss: 0.0001, Generator Loss: 13.4831
# Epoch: 63/100, Batch 41/44,Discriminator Loss: 0.0076, Generator Loss: 7.6114
# Epoch: 64/100, Batch 1/44,Discriminator Loss: 0.0228, Generator Loss: 6.0763
# Epoch: 64/100, Batch 11/44,Discriminator Loss: 0.0097, Generator Loss: 6.7226
# Epoch: 64/100, Batch 21/44,Discriminator Loss: 0.0075, Generator Loss: 6.2665
# Epoch: 64/100, Batch 31/44,Discriminator Loss: 0.0126, Generator Loss: 7.0358
# Epoch: 64/100, Batch 41/44,Discriminator Loss: 0.0039, Generator Loss: 6.7585
# Epoch: 65/100, Batch 1/44,Discriminator Loss: 0.0043, Generator Loss: 6.6460
# Epoch: 65/100, Batch 11/44,Discriminator Loss: 0.0056, Generator Loss: 6.5262
# Epoch: 65/100, Batch 21/44,Discriminator Loss: 0.0064, Generator Loss: 7.0826
# Epoch: 65/100, Batch 31/44,Discriminator Loss: 0.0044, Generator Loss: 7.2863
# Epoch: 65/100, Batch 41/44,Discriminator Loss: 0.0041, Generator Loss: 7.1449
# Epoch: 66/100, Batch 1/44,Discriminator Loss: 0.0050, Generator Loss: 7.9272
# Epoch: 66/100, Batch 11/44,Discriminator Loss: 0.0066, Generator Loss: 7.9485
# Epoch: 66/100, Batch 21/44,Discriminator Loss: 0.0111, Generator Loss: 8.5358
# Epoch: 66/100, Batch 31/44,Discriminator Loss: 0.0046, Generator Loss: 7.1044
# Epoch: 66/100, Batch 41/44,Discriminator Loss: 0.0035, Generator Loss: 9.3240
# Epoch: 67/100, Batch 1/44,Discriminator Loss: 0.0058, Generator Loss: 8.1888
# Epoch: 67/100, Batch 11/44,Discriminator Loss: 0.0035, Generator Loss: 7.2834
# Epoch: 67/100, Batch 21/44,Discriminator Loss: 0.0034, Generator Loss: 7.4772
# Epoch: 67/100, Batch 31/44,Discriminator Loss: 0.0099, Generator Loss: 7.0720
# Epoch: 67/100, Batch 41/44,Discriminator Loss: 0.0021, Generator Loss: 6.9789
# Epoch: 68/100, Batch 1/44,Discriminator Loss: 0.0006, Generator Loss: 17.2084
# Epoch: 68/100, Batch 11/44,Discriminator Loss: 0.0025, Generator Loss: 7.4134
# Epoch: 68/100, Batch 21/44,Discriminator Loss: 0.0049, Generator Loss: 7.6098
# Epoch: 68/100, Batch 31/44,Discriminator Loss: 0.0020, Generator Loss: 7.4767
# Epoch: 68/100, Batch 41/44,Discriminator Loss: 0.0032, Generator Loss: 8.0080
# Epoch: 69/100, Batch 1/44,Discriminator Loss: 0.0517, Generator Loss: 25.7011
# Epoch: 69/100, Batch 11/44,Discriminator Loss: 0.0122, Generator Loss: 32.2488
# Epoch: 69/100, Batch 21/44,Discriminator Loss: 0.0005, Generator Loss: 32.1575
# Epoch: 69/100, Batch 31/44,Discriminator Loss: 0.0002, Generator Loss: 32.1136
# Epoch: 69/100, Batch 41/44,Discriminator Loss: 0.0003, Generator Loss: 32.0872
# Epoch: 70/100, Batch 1/44,Discriminator Loss: 0.0018, Generator Loss: 32.0747
# Epoch: 70/100, Batch 11/44,Discriminator Loss: 0.0001, Generator Loss: 32.0512
# Epoch: 70/100, Batch 21/44,Discriminator Loss: 0.0004, Generator Loss: 32.0329
# Epoch: 70/100, Batch 31/44,Discriminator Loss: 0.0003, Generator Loss: 32.0075
# Epoch: 70/100, Batch 41/44,Discriminator Loss: 0.0001, Generator Loss: 31.9836
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_70.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_70.pth
# Epoch: 71/100, Batch 1/44,Discriminator Loss: 0.0001, Generator Loss: 31.9761
# Epoch: 71/100, Batch 11/44,Discriminator Loss: 0.0001, Generator Loss: 31.9504
# Epoch: 71/100, Batch 21/44,Discriminator Loss: 0.0001, Generator Loss: 31.9241
# Epoch: 71/100, Batch 31/44,Discriminator Loss: 0.0001, Generator Loss: 31.8797
# Epoch: 71/100, Batch 41/44,Discriminator Loss: 0.0001, Generator Loss: 31.8080
# Epoch: 72/100, Batch 1/44,Discriminator Loss: 0.0000, Generator Loss: 31.7681
# Epoch: 72/100, Batch 11/44,Discriminator Loss: 0.0001, Generator Loss: 31.5630
# Epoch: 72/100, Batch 21/44,Discriminator Loss: 0.0002, Generator Loss: 30.2412
# Epoch: 72/100, Batch 31/44,Discriminator Loss: 0.0002, Generator Loss: 23.8379
# Epoch: 72/100, Batch 41/44,Discriminator Loss: 0.0452, Generator Loss: 14.6523
# Epoch: 73/100, Batch 1/44,Discriminator Loss: 0.0017, Generator Loss: 9.7849
# Epoch: 73/100, Batch 11/44,Discriminator Loss: 0.0475, Generator Loss: 14.1746
# Epoch: 73/100, Batch 21/44,Discriminator Loss: 0.0016, Generator Loss: 26.4728
# Epoch: 73/100, Batch 31/44,Discriminator Loss: 0.0016, Generator Loss: 14.0589
# Epoch: 73/100, Batch 41/44,Discriminator Loss: 0.0016, Generator Loss: 11.3162
# Epoch: 74/100, Batch 1/44,Discriminator Loss: 0.0579, Generator Loss: 18.6523
# Epoch: 74/100, Batch 11/44,Discriminator Loss: 0.4666, Generator Loss: 22.7163
# Epoch: 74/100, Batch 21/44,Discriminator Loss: 0.1225, Generator Loss: 13.9381
# Epoch: 74/100, Batch 31/44,Discriminator Loss: 0.0076, Generator Loss: 11.1082
# Epoch: 74/100, Batch 41/44,Discriminator Loss: 0.0032, Generator Loss: 21.6453
# Epoch: 75/100, Batch 1/44,Discriminator Loss: 0.0000, Generator Loss: 16.2641
# Epoch: 75/100, Batch 11/44,Discriminator Loss: 0.0388, Generator Loss: 8.6501
# Epoch: 75/100, Batch 21/44,Discriminator Loss: 0.0100, Generator Loss: 20.6435
# Epoch: 75/100, Batch 31/44,Discriminator Loss: 0.0092, Generator Loss: 12.2947
# Epoch: 75/100, Batch 41/44,Discriminator Loss: 0.0401, Generator Loss: 7.7891
# Epoch: 76/100, Batch 1/44,Discriminator Loss: 0.0165, Generator Loss: 6.0429
# Epoch: 76/100, Batch 11/44,Discriminator Loss: 0.1134, Generator Loss: 17.6655
# Epoch: 76/100, Batch 21/44,Discriminator Loss: 0.0138, Generator Loss: 8.3127
# Epoch: 76/100, Batch 31/44,Discriminator Loss: 0.0327, Generator Loss: 12.8320
# Epoch: 76/100, Batch 41/44,Discriminator Loss: 0.0101, Generator Loss: 5.0306
# Epoch: 77/100, Batch 1/44,Discriminator Loss: 0.2541, Generator Loss: 26.3817
# Epoch: 77/100, Batch 11/44,Discriminator Loss: 0.0015, Generator Loss: 21.9138
# Epoch: 77/100, Batch 21/44,Discriminator Loss: 0.0010, Generator Loss: 10.6007
# Epoch: 77/100, Batch 31/44,Discriminator Loss: 0.0361, Generator Loss: 6.8000
# Epoch: 77/100, Batch 41/44,Discriminator Loss: 0.5332, Generator Loss: 23.6392
# Epoch: 78/100, Batch 1/44,Discriminator Loss: 0.0006, Generator Loss: 22.8035
# Epoch: 78/100, Batch 11/44,Discriminator Loss: 0.0001, Generator Loss: 15.9075
# Epoch: 78/100, Batch 21/44,Discriminator Loss: 0.0117, Generator Loss: 13.5440
# Epoch: 78/100, Batch 31/44,Discriminator Loss: 0.0328, Generator Loss: 7.8170
# Epoch: 78/100, Batch 41/44,Discriminator Loss: 0.0412, Generator Loss: 12.3264
# Epoch: 79/100, Batch 1/44,Discriminator Loss: 0.1361, Generator Loss: 25.6642
# Epoch: 79/100, Batch 11/44,Discriminator Loss: 0.0005, Generator Loss: 7.1365
# Epoch: 79/100, Batch 21/44,Discriminator Loss: 0.0047, Generator Loss: 6.9187
# Epoch: 79/100, Batch 31/44,Discriminator Loss: 0.0426, Generator Loss: 5.7557
# Epoch: 79/100, Batch 41/44,Discriminator Loss: 0.0585, Generator Loss: 8.7181
# Epoch: 80/100, Batch 1/44,Discriminator Loss: 0.0714, Generator Loss: 9.3154
# Epoch: 80/100, Batch 11/44,Discriminator Loss: 0.0170, Generator Loss: 7.0855
# Epoch: 80/100, Batch 21/44,Discriminator Loss: 0.0199, Generator Loss: 6.2571
# Epoch: 80/100, Batch 31/44,Discriminator Loss: 0.0157, Generator Loss: 7.1577
# Epoch: 80/100, Batch 41/44,Discriminator Loss: 0.6623, Generator Loss: 18.9931
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_80.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_80.pth
# Epoch: 81/100, Batch 1/44,Discriminator Loss: 0.0000, Generator Loss: 13.4644
# Epoch: 81/100, Batch 11/44,Discriminator Loss: 0.0100, Generator Loss: 5.9386
# Epoch: 81/100, Batch 21/44,Discriminator Loss: 0.0196, Generator Loss: 7.0521
# Epoch: 81/100, Batch 31/44,Discriminator Loss: 0.0194, Generator Loss: 6.0433
# Epoch: 81/100, Batch 41/44,Discriminator Loss: 0.0117, Generator Loss: 6.7942
# Epoch: 82/100, Batch 1/44,Discriminator Loss: 0.0339, Generator Loss: 6.5769
# Epoch: 82/100, Batch 11/44,Discriminator Loss: 0.0270, Generator Loss: 6.5354
# Epoch: 82/100, Batch 21/44,Discriminator Loss: 0.0278, Generator Loss: 8.6361
# Epoch: 82/100, Batch 31/44,Discriminator Loss: 0.0198, Generator Loss: 6.7356
# Epoch: 82/100, Batch 41/44,Discriminator Loss: 0.0091, Generator Loss: 6.5303
# Epoch: 83/100, Batch 1/44,Discriminator Loss: 0.0186, Generator Loss: 8.0036
# Epoch: 83/100, Batch 11/44,Discriminator Loss: 0.0219, Generator Loss: 8.8331
# Epoch: 83/100, Batch 21/44,Discriminator Loss: 0.0252, Generator Loss: 7.4766
# Epoch: 83/100, Batch 31/44,Discriminator Loss: 0.0174, Generator Loss: 6.4490
# Epoch: 83/100, Batch 41/44,Discriminator Loss: 0.0096, Generator Loss: 6.6554
# Epoch: 84/100, Batch 1/44,Discriminator Loss: 0.0150, Generator Loss: 6.9353
# Epoch: 84/100, Batch 11/44,Discriminator Loss: 0.0149, Generator Loss: 7.0775
# Epoch: 84/100, Batch 21/44,Discriminator Loss: 0.0057, Generator Loss: 6.5036
# Epoch: 84/100, Batch 31/44,Discriminator Loss: 0.0107, Generator Loss: 6.9438
# Epoch: 84/100, Batch 41/44,Discriminator Loss: 0.0108, Generator Loss: 7.6642
# Epoch: 85/100, Batch 1/44,Discriminator Loss: 0.0065, Generator Loss: 6.9574
# Epoch: 85/100, Batch 11/44,Discriminator Loss: 0.0076, Generator Loss: 8.1871
# Epoch: 85/100, Batch 21/44,Discriminator Loss: 0.0046, Generator Loss: 6.4715
# Epoch: 85/100, Batch 31/44,Discriminator Loss: 0.0052, Generator Loss: 6.7874
# Epoch: 85/100, Batch 41/44,Discriminator Loss: 0.0092, Generator Loss: 6.7611
# Epoch: 86/100, Batch 1/44,Discriminator Loss: 0.0043, Generator Loss: 6.8976
# Epoch: 86/100, Batch 11/44,Discriminator Loss: 0.0095, Generator Loss: 6.7409
# Epoch: 86/100, Batch 21/44,Discriminator Loss: 0.0033, Generator Loss: 6.5742
# Epoch: 86/100, Batch 31/44,Discriminator Loss: 0.0133, Generator Loss: 6.8214
# Epoch: 86/100, Batch 41/44,Discriminator Loss: 0.0074, Generator Loss: 7.5348
# Epoch: 87/100, Batch 1/44,Discriminator Loss: 0.0071, Generator Loss: 8.1281
# Epoch: 87/100, Batch 11/44,Discriminator Loss: 0.0083, Generator Loss: 7.2753
# Epoch: 87/100, Batch 21/44,Discriminator Loss: 0.0113, Generator Loss: 7.5679
# Epoch: 87/100, Batch 31/44,Discriminator Loss: 0.0002, Generator Loss: 12.6461
# Epoch: 87/100, Batch 41/44,Discriminator Loss: 0.0087, Generator Loss: 6.0245
# Epoch: 88/100, Batch 1/44,Discriminator Loss: 0.0075, Generator Loss: 6.4900
# Epoch: 88/100, Batch 11/44,Discriminator Loss: 0.0065, Generator Loss: 6.9948
# Epoch: 88/100, Batch 21/44,Discriminator Loss: 0.0177, Generator Loss: 7.5948
# Epoch: 88/100, Batch 31/44,Discriminator Loss: 0.0050, Generator Loss: 8.3792
# Epoch: 88/100, Batch 41/44,Discriminator Loss: 0.0064, Generator Loss: 7.7666
# Epoch: 89/100, Batch 1/44,Discriminator Loss: 0.0123, Generator Loss: 6.9424
# Epoch: 89/100, Batch 11/44,Discriminator Loss: 0.0191, Generator Loss: 6.9140
# Epoch: 89/100, Batch 21/44,Discriminator Loss: 0.0073, Generator Loss: 7.1367
# Epoch: 89/100, Batch 31/44,Discriminator Loss: 0.0029, Generator Loss: 7.2400
# Epoch: 89/100, Batch 41/44,Discriminator Loss: 0.0091, Generator Loss: 7.0434
# Epoch: 90/100, Batch 1/44,Discriminator Loss: 0.0049, Generator Loss: 7.5379
# Epoch: 90/100, Batch 11/44,Discriminator Loss: 0.0095, Generator Loss: 6.3881
# Epoch: 90/100, Batch 21/44,Discriminator Loss: 0.0070, Generator Loss: 6.4359
# Epoch: 90/100, Batch 31/44,Discriminator Loss: 0.0029, Generator Loss: 6.9724
# Epoch: 90/100, Batch 41/44,Discriminator Loss: 0.0052, Generator Loss: 6.5532
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/discriminator/discriminator_90.pth
# [INFO] Saving model to: /content/gdive/MyDrive/GIDS/saved_model/dcgan/generator/generator_90.pth
# Epoch: 91/100, Batch 1/44,Discriminator Loss: 0.0041, Generator Loss: 7.6031
# Epoch: 91/100, Batch 11/44,Discriminator Loss: 0.0097, Generator Loss: 6.5300
# Epoch: 91/100, Batch 21/44,Discriminator Loss: 0.0116, Generator Loss: 6.5251
# Epoch: 91/100, Batch 31/44,Discriminator Loss: 0.0121, Generator Loss: 8.1873
# Epoch: 91/100, Batch 41/44,Discriminator Loss: 0.0126, Generator Loss: 8.3717
# Epoch: 92/100, Batch 1/44,Discriminator Loss: 0.0143, Generator Loss: 9.9789
# Epoch: 92/100, Batch 11/44,Discriminator Loss: 0.0047, Generator Loss: 7.4877
# Epoch: 92/100, Batch 21/44,Discriminator Loss: 0.0086, Generator Loss: 7.2722
# Epoch: 92/100, Batch 31/44,Discriminator Loss: 0.0042, Generator Loss: 6.8201
# Epoch: 92/100, Batch 41/44,Discriminator Loss: 0.0043, Generator Loss: 7.0434
# Epoch: 93/100, Batch 1/44,Discriminator Loss: 0.0032, Generator Loss: 6.9382
# Epoch: 93/100, Batch 11/44,Discriminator Loss: 0.0043, Generator Loss: 6.9263
# Epoch: 93/100, Batch 21/44,Discriminator Loss: 0.0049, Generator Loss: 7.2986
# Epoch: 93/100, Batch 31/44,Discriminator Loss: 0.0023, Generator Loss: 7.3121
# Epoch: 93/100, Batch 41/44,Discriminator Loss: 0.0052, Generator Loss: 6.6095
# Epoch: 94/100, Batch 1/44,Discriminator Loss: 0.0036, Generator Loss: 6.8303
# Epoch: 94/100, Batch 11/44,Discriminator Loss: 0.0242, Generator Loss: 12.6718
# Epoch: 94/100, Batch 21/44,Discriminator Loss: 0.0107, Generator Loss: 8.7855
# Epoch: 94/100, Batch 31/44,Discriminator Loss: 0.0021, Generator Loss: 9.0411
# Epoch: 94/100, Batch 41/44,Discriminator Loss: 0.0068, Generator Loss: 6.7138
# Epoch: 95/100, Batch 1/44,Discriminator Loss: 0.0041, Generator Loss: 7.8024
# Epoch: 95/100, Batch 11/44,Discriminator Loss: 0.0039, Generator Loss: 8.1305
# Epoch: 95/100, Batch 21/44,Discriminator Loss: 0.0058, Generator Loss: 8.4114
# Epoch: 95/100, Batch 31/44,Discriminator Loss: 0.0077, Generator Loss: 7.6533
# Epoch: 95/100, Batch 41/44,Discriminator Loss: 0.0144, Generator Loss: 11.2508
# Epoch: 96/100, Batch 1/44,Discriminator Loss: 0.0016, Generator Loss: 8.2196
# Epoch: 96/100, Batch 11/44,Discriminator Loss: 0.0020, Generator Loss: 7.5547
# Epoch: 96/100, Batch 21/44,Discriminator Loss: 0.0018, Generator Loss: 7.8945
# Epoch: 96/100, Batch 31/44,Discriminator Loss: 0.0218, Generator Loss: 6.6011
# Epoch: 96/100, Batch 41/44,Discriminator Loss: 0.0219, Generator Loss: 13.3338
# Epoch: 97/100, Batch 1/44,Discriminator Loss: 0.0021, Generator Loss: 13.2477
# Epoch: 97/100, Batch 11/44,Discriminator Loss: 0.0030, Generator Loss: 7.4698
# Epoch: 97/100, Batch 21/44,Discriminator Loss: 0.0039, Generator Loss: 7.7910
# Epoch: 97/100, Batch 31/44,Discriminator Loss: 0.0020, Generator Loss: 7.5839
# Epoch: 97/100, Batch 41/44,Discriminator Loss: 0.0012, Generator Loss: 8.3499
# Epoch: 98/100, Batch 1/44,Discriminator Loss: 0.0033, Generator Loss: 7.8174
# Epoch: 98/100, Batch 11/44,Discriminator Loss: 0.0063, Generator Loss: 8.7517
# Epoch: 98/100, Batch 21/44,Discriminator Loss: 0.0075, Generator Loss: 7.9128
# Epoch: 98/100, Batch 31/44,Discriminator Loss: 0.0107, Generator Loss: 10.3848
# Epoch: 98/100, Batch 41/44,Discriminator Loss: 0.0023, Generator Loss: 7.0587
# Epoch: 99/100, Batch 1/44,Discriminator Loss: 0.0032, Generator Loss: 7.6446
# Epoch: 99/100, Batch 11/44,Discriminator Loss: 0.0029, Generator Loss: 8.1987
# Epoch: 99/100, Batch 21/44,Discriminator Loss: 0.0055, Generator Loss: 7.0357
# Epoch: 99/100, Batch 31/44,Discriminator Loss: 0.0077, Generator Loss: 8.9742
# Epoch: 99/100, Batch 41/44,Discriminator Loss: 0.0166, Generator Loss: 21.2687
